# %%
from qiskit.circuit.library import QFT
from qiskit.quantum_info import Statevector
from qiskit import QuantumCircuit
from qiskit.visualization import plot_bloch_multivector
import warnings
warnings.filterwarnings('ignore')

# %%
state = '001'

qc = QuantumCircuit (len(state))
qc.initialize(Statevector.from_label(state).data, qc.qubits[::-1])
print(f'Comuputational Basis | {state}>')
display(plot_bloch_multivector(Statevector.from_instruction(qc).data))

print(f'Fourier Basis | {state}>')
qc.append(QFT(len(state), do_swaps=True), qc.qubits)
display(plot_bloch_multivector(Statevector.from_instruction(qc).data))
# Out:
# Comuputational Basis | 001>
# Fourier Basis | 001>
